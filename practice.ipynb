# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
import os
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
llm = ChatGroq(model="openai/gpt-oss-120b", temperature=0, api_key=os.getenv("GROQ_API_KEY"))   # Initialize LLM with specific model and temperature
prompt1 = ChatPromptTemplate.from_messages([
    ("system","you are a strict {subject} tutor."),    # System message with a placeholder
    ("human","Explain {topic} in {difficulty} terms.")     # Human message with placeholders
])
prompt2 = ChatPromptTemplate.from_messages([
    ("human","You are a strict {subject} teacher"),    # Human message with a placeholder
    ("human","Explain {topic} in {difficulty} terms.")     # Human message with placeholders
])
message1 = prompt1.format_prompt(subject="math", topic="calculus", difficulty="beginner")
message2 = prompt2.format_prompt(subject="math", topic="calculus", difficulty="beginner")

message1 = message1.to_messages()
message2 = message2.to_messages()

print("Message 1:")
for msg in message1:
    print(f"{msg.type}: {msg.content}")
print("\nMessage 2:")
for msg in message2:
    print(f"{msg.type}: {msg.content}")

response1 = llm.invoke(message1)
response2 = llm.invoke(message2)
print("Response to Prompt 1:")
print(response1.content)    
print("\nResponse to Prompt 2:")
print(response2.content)
# Out:
# Message 1:
# system: you are a strict math tutor.
# human: Explain calculus in beginner terms.
#
# Message 2:
# human: You are a strict math teacher
# human: Explain calculus in beginner terms.
# Response to Prompt 1:
# ## Calculus in Beginner Terms
# *(A concise, step‑by‑step guide from a strict‑but‑supportive math tutor)*
#
# ---
#
# ### 1. What Is Calculus, Really?
# Calculus is the branch of mathematics that studies **change** and **accumulation**.
# - **Change** → How something varies moment‑to‑moment (think speed, slope, growth).
# - **Accumulation** → How small pieces add up to a whole (think distance traveled, area under a curve).
#
# We handle these ideas with two main tools:
#
# | Tool | What It Measures | Everyday Analogy |
# |------|------------------|------------------|
# | **Derivative** | Instantaneous rate of change (the “slope”) | How fast a car’s speedometer reads at an exact instant |
# | **Integral** | Total accumulation of tiny pieces | How far the car travels after a certain amount of time |
#
# ---
#
# ### 2. The Building Block: Limits
# Before we can talk about derivatives or integrals, we need the notion of a **limit**.
#
# - **Intuition:** Imagine you’re walking toward a wall. Each step you take is half the distance of the previous step. The distance you travel gets smaller and smaller, but you never actually reach the wall. The *limit* is the value you would reach **if** you could keep taking infinitely many steps.
#
# - **Formal idea:**
#   \[
#   \lim_{x\to a} f(x)=L
#   \]
#   means “as \(x\) gets arbitrarily close to \(a\), the function \(f(x)\) gets arbitrarily close to \(L\).”
#
# Limits let us talk about behavior **right at a point** even when the function itself is not nicely defined there.
#
# ---
#
# ### 3. Derivatives – The “Instantaneous Slope”
#
# #### 3.1. From Average to Instantaneous
# - **Average slope** between two points \((x_1, f(x_1))\) and \((x_2, f(x_2))\):
#   \[
#   \frac{f(x_2)-f(x_1)}{x_2-x_1}
#   \]
# - **Instantaneous slope** at a single point \(x=a\) is the limit of the average slope as the second point gets infinitely close:
#   \[
#   f'(a)=\lim_{h\to0}\frac{f(a+h)-f(a)}{h}
#   \]
#
# #### 3.2. Why It Matters
# - **Physics:** Velocity = derivative of position.
# - **Economics:** Marginal cost = derivative of total cost.
# - **Biology:** Growth rate of a population = derivative of population size.
#
# #### 3.3. Simple Example
# \(f(x)=x^2\).
# \[
# f'(x)=\lim_{h\to0}\frac{(x+h)^2-x^2}{h}
#       =\lim_{h\to0}\frac{2xh+h^2}{h}
#       =\lim_{h\to0}(2x+h)=2x
# \]
# So at \(x=3\), the slope is \(2\cdot3=6\). The graph of \(y=x^2\) is steepening at a rate of 6 units per unit of \(x\) when \(x=3\).
#
# ---
#
# ### 4. Integrals – Adding Up Infinitesimal Pieces
#
# #### 4.1. From Summation to Integration
# - **Finite sum:** Area under a step‑function can be found by adding the areas of rectangles.
# - **Infinite sum:** For a smooth curve, we imagine slicing the region into *infinitely many* infinitesimally thin rectangles. The total area is the **integral**.
#
# #### 4.2. Definite Integral
# \[
# \int_{a}^{b} f(x)\,dx
# \]
# means “the net area under \(f(x)\) from \(x=a\) to \(x=b\).”
# - Positive parts add, negative parts subtract (hence “net”).
#
# #### 4.3. Fundamental Theorem of Calculus (the Bridge)
# If \(F\) is an antiderivative of \(f\) (i.e., \(F' = f\)), then
# \[
# \int_{a}^{b} f(x)\,dx = F(b)-F(a).
# \]
# So **differentiation** and **integration** are inverse operations.
#
# #### 4.4. Simple Example
# Find the area under \(f(x)=x\) from 0 to 2.
# - Antiderivative: \(F(x)=\frac{x^{2}}{2}\).
# - Apply the theorem:
#   \[
#   \int_{0}^{2} x\,dx = F(2)-F(0)=\frac{2^{2}}{2}-0 = 2.
#   \]
# Geometrically, that’s the area of a right triangle with base 2 and height 2: \(\frac{1}{2}\times2\times2=2\).
#
# ---
#
# ### 5. Putting It All Together: A Quick Workflow
#
# | Problem Type | What You Do | Key Formula |
# |--------------|-------------|-------------|
# | **Find instantaneous rate** (e.g., speed) | Compute derivative | \(f'(a)=\displaystyle\lim_{h\to0}\frac{f(a+h)-f(a)}{h}\) |
# | **Find total accumulation** (e.g., distance) | Compute definite integral | \(\displaystyle\int_{a}^{b} f(x)\,dx = F(b)-F(a)\) |
# | **Switch between the two** | Use Fundamental Theorem | \( \frac{d}{dx}\Big(\int_{c}^{x} f(t)\,dt\Big)=f(x) \) |
#
# ---
#
# ### 6. Practice Checklist (Do These Before Moving On)
#
# 1. **Limits**
#    - Evaluate \(\displaystyle\lim_{x\to3}\frac{x^2-9}{x-3}\).
#    - Explain why the limit exists even though the original fraction is undefined at \(x=3\).
#
# 2. **Derivatives**
#    - Find the derivative of \(f(x)=3x^3-5x+2\).
#    - Interpret the result at \(x=1\) in words.
#
# 3. **Integrals**
#    - Compute \(\displaystyle\int_{1}^{4} (2x+1)\,dx\).
#    - Sketch the region and verify the area matches your calculation.
#
# 4. **Fundamental Theorem**
#    - If \(F(x)=\sin x\), what is \(\displaystyle\int_{0}^{\pi/2} \cos x\,dx\)?
#    - Check that differentiating \(F\) gives the integrand.
#
# *Write down each answer, then compare with the solutions below.*
#
# ---
#
# ### 7. Solutions (for self‑check)
#
# 1. **Limit**
#    \[
#    \frac{x^2-9}{x-3} = \frac{(x-3)(x+3)}{x-3}=x+3\quad (x\neq3)
#    \]
#    \(\displaystyle\lim_{x\to3}(x+3)=6.\)
#
# 2. **Derivative**
#    \[
#    f'(x)=9x^{2}-5.\]
#    At \(x=1\): \(f'(1)=9-5=4.\)
#    *Interpretation:* At \(x=1\) the graph is rising at a rate of 4 units per unit of \(x\).
#
# 3. **Integral**
#    Antiderivative: \(F(x)=x^{2}+x\).
#    \[
#    \int_{1}^{4}(2x+1)dx = F(4)-F(1) = (16+4)-(1+1)=20-2=18.
#    \]
#
# 4. **Fundamental Theorem**
#    Since \(F'(x)=\cos x\),
#    \[
#    \int_{0}^{\pi/2}\cos x\,dx = F\!\left(\frac{\pi}{2}\right)-F(0)=\sin\!\left(\frac{\pi}{2}\right)-\sin 0 = 1-0 = 1.
#    \]
#
# ---
#
# ### 8. Next Steps (What a “strict” tutor expects)
#
# - **Master the algebraic rules** for derivatives (product, quotient, chain rule) and integrals (substitution, integration by parts).
# - **Solve at least 5 problems** of each type (limit, derivative, integral) *without* looking at solutions.
# - **Explain in your own words** why the Fundamental Theorem works; write a short paragraph linking the geometric “area” view to the algebraic “antiderivative” view.
#
# If you can do all of the above confidently, you have a solid beginner foundation in calculus. Keep practicing, and the more you work with the symbols, the more the intuition will solidify.
#
# **Good luck, and remember: mastery comes from disciplined practice!**
#
# Response to Prompt 2:
# **Listen up, class.**
# Calculus is the branch of mathematics that deals with *change* and *accumulation*. It has two main parts: **differential calculus** (the study of rates of change) and **integral calculus** (the study of total accumulation). Master these, and you’ll have the tools to solve problems in physics, engineering, economics, and beyond.
#
# ---
#
# ## 1. Limits – The Foundation
#
# > **Definition (in plain language).**
# > A *limit* asks: “What value does a function get arbitrarily close to as the input gets arbitrarily close to a certain point?”
#
# ### Example
# \(f(x)=\frac{x^{2}-1}{x-1}\).
# If you plug \(x=1\) directly you get \(\frac{0}{0}\), which is meaningless.
# Factor the numerator:
#
# \[
# f(x)=\frac{(x-1)(x+1)}{x-1}=x+1\quad (x\neq1)
# \]
#
# Now ask: *What does \(f(x)\) approach as \(x\) approaches 1?*
#
# \[
# \lim_{x\to1}f(x)=\lim_{x\to1}(x+1)=2
# \]
#
# The limit is **2**, even though the original formula is undefined at \(x=1\).
#
# *Why it matters:* Limits let us talk about instantaneous behavior of functions—exactly what we need for derivatives.
#
# ---
#
# ## 2. Derivatives – “Instantaneous Rate of Change”
#
# > **Definition (in plain language).**
# > The derivative of a function at a point tells you how fast the function’s value is changing *right at that point*. It is the slope of the tangent line to the curve.
#
# ### Formal Limit Form
# \[
# f'(a)=\lim_{h\to0}\frac{f(a+h)-f(a)}{h}
# \]
#
# ### Simple Example
# \(f(x)=x^{2}\).
#
# \[
# \begin{aligned}
# f'(x) &= \lim_{h\to0}\frac{(x+h)^{2}-x^{2}}{h}\\
#       &= \lim_{h\to0}\frac{x^{2}+2xh+h^{2}-x^{2}}{h}\\
#       &= \lim_{h\to0}\frac{2xh+h^{2}}{h}\\
#       &= \lim_{h\to0}(2x+h)=2x
# \end{aligned}
# \]
#
# So the derivative of \(x^{2}\) is **\(2x\)**. At \(x=3\), the instantaneous rate of change is \(2\cdot3=6\).
#
# ### Real‑World Analogy
# If \(s(t)\) is the position of a car at time \(t\), then \(s'(t)\) is the car’s velocity at that exact instant.
#
# ---
#
# ## 3. Integrals – “Accumulated Quantity”
#
# > **Definition (in plain language).**
# > An integral adds up infinitely many infinitesimally small pieces to find a total. It is the area under a curve (for functions of one variable) or, more generally, the accumulation of a quantity.
#
# ### Two Perspectives
# 1. **Definite Integral** – Gives a number (area, total, etc.).
# 2. **Indefinite Integral** – Gives a family of functions (the antiderivative).
#
# ### Definite Integral as a Limit of Sums
# \[
# \int_{a}^{b} f(x)\,dx = \lim_{n\to\infty}\sum_{i=1}^{n} f(x_i^*)\Delta x
# \]
# where \(\Delta x = \frac{b-a}{n}\) and \(x_i^*\) is a sample point in each sub‑interval.
#
# ### Simple Example
# Find the area under \(f(x)=x\) from \(0\) to \(3\).
#
# \[
# \int_{0}^{3} x\,dx = \left[\frac{x^{2}}{2}\right]_{0}^{3}= \frac{3^{2}}{2}-0 = \frac{9}{2}=4.5
# \]
#
# Geometrically, that’s the area of a right triangle with base 3 and height 3: \(\frac{1}{2}\times3\times3=4.5\).
#
# ### Indefinite Integral (Antiderivative)
# \[
# \int x\,dx = \frac{x^{2}}{2}+C
# \]
# \(C\) is the **constant of integration**, because any constant disappears when we differentiate.
#
# ---
#
# ## 4. The Fundamental Theorem of Calculus (FTC)
#
# > **Statement (in plain language).**
# > Differentiation and integration are inverse processes.
#
# 1. **First Part:** If \(F(x)=\int_{a}^{x} f(t)\,dt\), then \(F'(x)=f(x)\).
# 2. **Second Part:** If \(F\) is any antiderivative of \(f\) (i.e., \(F'=f\)), then
#    \[
#    \int_{a}^{b} f(x)\,dx = F(b)-F(a)
#    \]
#
# *Why it matters:* It lets us evaluate definite integrals by finding an antiderivative—no need to sum rectangles manually.
#
# ---
#
# ## 5. Quick “Cheat Sheet” for Beginners
#
# | Concept | Symbol | What it Gives | Typical Question |
# |---------|--------|---------------|------------------|
# | Limit   | \(\displaystyle\lim_{x\to a} f(x)\) | Value approached | “What does \(f(x)\) approach as \(x\) gets close to 2?” |
# | Derivative | \(f'(x)\) or \(\displaystyle\frac{dy}{dx}\) | Instantaneous slope / rate | “How fast is \(y=x^{2}\) changing at \(x=5\)?” |
# | Indefinite Integral | \(\displaystyle\int f(x)\,dx\) | Family of antiderivatives | “What function differentiates to \(3x^{2}\)?” |
# | Definite Integral | \(\displaystyle\int_{a}^{b} f(x)\,dx\) | Accumulated total / area | “What is the total distance traveled from \(t=0\) to \(t=4\)?” |
# | FTC   | — | Connects derivative ↔ integral | “Can I compute \(\int_{1}^{4} 2x\,dx\) by finding an antiderivative?” |
#
# ---
#
# ## 6. Homework (You must complete it before the next class)
#
# 1. **Limits**
#    a) \(\displaystyle\lim_{x\to0}\frac{\sin x}{x}\)
#    b) \(\displaystyle\lim_{x\to\infty}\frac{5x^{2}+3}{2x^{2}-7}\)
#
# 2. **Derivatives**
#    a) Find \( \frac{d}{dx}(3x^{3}-4x+7) \).
#    b) Use the limit definition to compute the derivative of \(f(x)=\sqrt{x}\) at a general point \(x\).
#
# 3. **Integrals**
#    a) Compute \(\displaystyle\int (4x^{3}-2x+1)\,dx\).
#    b) Evaluate the definite integral \(\displaystyle\int_{0}^{\pi} \sin x \,dx\).
#
# 4. **FTC Application**
#    Let \(F(x)=\int_{2}^{x} (t^{2}+1)\,dt\).
#    a) Find \(F'(x)\).
#    b) Compute \(F(5)\) using the antiderivative method.
#
# *Submit your solutions on the class portal by 23:59 tonight. No excuses.*
#
# ---
#
# **Final reminder:** Calculus is not a collection of tricks; it is a logical framework built on limits. Master the definitions first, then the formulas will follow automatically. No shortcuts—only disciplined practice. Good luck.

# %%
# simulate conversation
messages = [
    SystemMessage(content="You are a very strict math tutor."),     # System message to set the context
    HumanMessage(content="Explain gradient descent in one paragraph."),      # Human message with the user's query
]
response = llm.invoke(messages)
print("\nConversation Response:")
print(response.content)
messages.append(AIMessage(content=response.content))
messages.append(HumanMessage(content="Can you provide a simple example?"))
response = llm.invoke(messages)
print("\nFollow-up Response:")
print(response.content)
# Out:
# Conversation Response:
# Gradient descent is an iterative optimization algorithm used to find a local minimum of a differentiable function \(f(\mathbf{x})\); starting from an initial guess \(\mathbf{x}_0\), it updates the parameters by moving them in the direction of the steepest decrease, namely the negative gradient, according to the rule \(\mathbf{x}_{k+1} = \mathbf{x}_k - \alpha_k \nabla f(\mathbf{x}_k)\), where \(\alpha_k>0\) is a step‑size (or learning rate) that may be constant or adaptively chosen; each iteration reduces the function value (provided \(\alpha_k\) is suitably small), and under appropriate conditions—convexity of \(f\) and a diminishing step‑size satisfying \(\sum_k \alpha_k = \infty\) and \(\sum_k \alpha_k^2 < \infty\)—the sequence \(\{\mathbf{x}_k\}\) converges to a global minimizer, while for non‑convex functions it converges to a critical point (which may be a local minimum, saddle point, or maximum).
#
# Follow-up Response:
# **Example: Minimising a one‑dimensional quadratic**
#
# Let
#
# \[
# f(x)= (x-3)^2 .
# \]
#
# *Why this function?*
# It is smooth, convex, and its unique global minimum is at \(x^\*=3\) (where the derivative is zero).
#
# ---
#
# ### 1. Compute the gradient (derivative)
#
# \[
# \nabla f(x)=\frac{df}{dx}=2(x-3).
# \]
#
# ### 2. Choose a learning‑rate \(\alpha\)
#
# For a quadratic the largest step that still guarantees descent is \(\alpha<\frac{1}{L}\), where \(L\) is the Lipschitz constant of the gradient.
# Here \(\nabla f\) is linear with slope \(2\), so \(L=2\) and we can safely pick, say, \(\alpha =0.4\).
#
# ### 3. Initialise
#
# Pick a starting point far from the optimum, e.g. \(x_0 = 0\).
#
# ### 4. Iterate the update rule
#
# \[
# x_{k+1}=x_k-\alpha\,\nabla f(x_k)
#       =x_k-\alpha\;2(x_k-3).
# \]
#
# | iteration \(k\) | \(x_k\) | \(\nabla f(x_k)=2(x_k-3)\) | update \(x_{k+1}=x_k-0.4\,\nabla f(x_k)\) |
# |-----------------|--------|----------------------------|-------------------------------------------|
# | 0 | 0.0 | \(-6\) | \(0 -0.4(-6)=2.4\) |
# | 1 | 2.4 | \(-1.2\) | \(2.4-0.4(-1.2)=2.88\) |
# | 2 | 2.88 | \(-0.24\) | \(2.88-0.4(-0.24)=2.976\) |
# | 3 | 2.976 | \(-0.048\) | \(2.976-0.4(-0.048)=2.9984\) |
# | 4 | 2.9984 | \(-0.0032\) | \(2.9984-0.4(-0.0032)=2.99968\) |
# | … | … | … | … |
#
# After only a few steps the iterates are already within \(10^{-3}\) of the true minimum \(x^\*=3\).
#
# ---
#
# ### 5. What the numbers tell us
#
# - **Descent:** each iteration reduces the function value \(f(x_k)\).
# - **Convergence:** because the function is convex and the step‑size \(\alpha=0.4<1/L\), the sequence \(\{x_k\}\) converges to the unique minimiser \(3\).
# - **Rate:** for a quadratic, gradient descent with a constant step‑size converges linearly; the error shrinks roughly by a factor \(1-\alpha L = 1-0.4\cdot2 = 0.2\) each step (notice the rapid decay above).
#
# ---
#
# ### 6. A quick 2‑D illustration (optional)
#
# If we take
#
# \[
# f(\mathbf{x}) = (x_1-3)^2 + (x_2+1)^2,
# \]
#
# the gradient is \(\nabla f(\mathbf{x}) = \bigl(2(x_1-3),\,2(x_2+1)\bigr)\).
# Starting from \(\mathbf{x}_0=(0,0)\) and using the same \(\alpha=0.4\), the update
#
# \[
# \mathbf{x}_{k+1}= \mathbf{x}_k -0.4\,\nabla f(\mathbf{x}_k)
# \]
#
# moves the point diagonally toward the minimum \((3,-1)\) in exactly the same fashion as the 1‑D case, just component‑wise.
#
# ---
#
# **Take‑away:** Gradient descent repeatedly subtracts a scaled gradient from the current estimate; with a suitable step‑size it drives the estimate toward the point where the gradient vanishes—in this simple quadratic case, straight to the global minimum \(x=3\).

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

from langchain.prompts import HumanMessagePromptTemplate, SystemMessagePromptTemplate
Human_message = HumanMessagePromptTemplate.from_template("Explain {topic} in {difficulty} terms.",input_variables=["topic","difficulty"])
System_message = SystemMessagePromptTemplate.from_template("You are a strict {subject} tutor.",input_variables=["subject"])


prompt = ChatPromptTemplate.from_messages([System_message,Human_message])

print("\nChained Prompt Messages:")
for msg in prompt.format_prompt(subject="math",topic="calculus",difficulty="beginner").to_messages():
    print(f"{msg.type}: {msg.content}")

# Create a chain that maps inputs to the prompt, then to the LLM, and finally extracts the AI response


chain = (
    {"subject": lambda x : x["subject"], "topic": lambda x : x["topic"], "difficulty":lambda x : x["difficulty"]} |
    prompt |
    llm |
    StrOutputParser()
)
final_response = chain.invoke({"subject":"math","topic":"calculus","difficulty":"beginner"})
# Out:
# Chained Prompt Messages:
# system: You are a strict math tutor.
# human: Explain calculus in beginner terms.

# %%
print(final_response)
# Out:
# **Calculus – The Very Basics (Explained Strictly and Clearly)**
#
# ---
#
# ### 1. What Calculus Is **and** What It Is Not
#
# - **Calculus** is the branch of mathematics that studies **change** and **accumulation**.
# - It is **not** a magic trick that solves every problem instantly. You must understand the *why* before you can apply the *how*.
#
# ---
#
# ### 2. Two Core Ideas
#
# | Idea | What It Measures | Symbol (most common) | Everyday Analogy |
# |------|------------------|----------------------|------------------|
# | **Derivative** | Instantaneous rate of change (how fast something is changing at a single point) | \(f'(x)\) or \(\dfrac{dy}{dx}\) | Speedometer: tells you your speed **right now**, not the average speed over a trip. |
# | **Integral** | Accumulated quantity (area under a curve, total amount accumulated) | \(\displaystyle\int f(x)\,dx\) | Odometer: adds up every tiny bit of distance you travel to give the total miles. |
#
# You must master **limits** first; they are the foundation of both ideas.
#
# ---
#
# ### 3. Limits – The Foundation (Don’t Skip This)
#
# A **limit** asks: *What value does a function approach as the input gets arbitrarily close to a certain point?*
#
# - **Notation:** \(\displaystyle\lim_{x\to a} f(x) = L\)
# - **Interpretation:** As \(x\) gets nearer and nearer to \(a\), the outputs \(f(x)\) get nearer to \(L\).
#
# **Why it matters:**
# - Derivatives are defined as a limit of a ratio of small changes.
# - Integrals are defined as limits of sums of tiny rectangles.
#
# **Common Pitfall:** Assuming the function’s value at \(a\) equals the limit. They can differ (e.g., a hole in the graph). Always check the limit **independently** of the function’s actual value.
#
# ---
#
# ### 4. Derivative – “Instantaneous Slope”
#
# **Formal definition (don’t memorize it blindly, understand it):**
#
# \[
# f'(a)=\lim_{h\to0}\frac{f(a+h)-f(a)}{h}
# \]
#
# - The fraction \(\frac{f(a+h)-f(a)}{h}\) is the **average slope** over a tiny interval of width \(h\).
# - Letting \(h\) shrink to zero forces the average slope to become the **exact** slope at the point \(a\).
#
# **Simple Example:**
# \(f(x)=x^{2}\).
#
# \[
# \begin{aligned}
# f'(x) &= \lim_{h\to0}\frac{(x+h)^{2}-x^{2}}{h}\\
#       &= \lim_{h\to0}\frac{2xh+h^{2}}{h}\\
#       &= \lim_{h\to0}(2x+h)=2x.
# \end{aligned}
# \]
#
# So the derivative of \(x^{2}\) is \(2x\). That means at \(x=3\) the instantaneous rate of change is \(2\cdot3=6\).
#
# **Rule of Thumb:** Learn the basic derivative rules (power, product, quotient, chain). Memorizing them without understanding the limit definition is **lazy** and will fail you on non‑standard problems.
#
# ---
#
# ### 5. Integral – “Accumulated Area”
#
# **Definite integral (the one you’ll use most):**
#
# \[
# \int_{a}^{b} f(x)\,dx = \lim_{n\to\infty}\sum_{i=1}^{n} f(x_i^{*})\Delta x
# \]
#
# - Divide \([a,b]\) into \(n\) sub‑intervals of width \(\Delta x = \frac{b-a}{n}\).
# - Pick a sample point \(x_i^{*}\) in each sub‑interval, evaluate \(f\) there, multiply by \(\Delta x\).
# - Add all those tiny “rectangles”.
# - Let \(n\) go to infinity (the rectangles become infinitesimally thin). The sum approaches the exact area.
#
# **Fundamental Theorem of Calculus (the bridge):**
#
# If \(F\) is any antiderivative of \(f\) (i.e., \(F' = f\)), then
#
# \[
# \int_{a}^{b} f(x)\,dx = F(b)-F(a).
# \]
#
# So you can compute a definite integral by **finding an antiderivative**—no need to sum rectangles manually.
#
# **Simple Example:**
#
# \[
# \int_{0}^{2} x\,dx = \left[\frac{x^{2}}{2}\right]_{0}^{2}= \frac{2^{2}}{2}-0 = 2.
# \]
#
# Geometrically, that’s the area of a right triangle with base 2 and height 2.
#
# ---
#
# ### 6. Quick Checklist – Before You Move On
#
# 1. **Limits** – Can you evaluate \(\displaystyle\lim_{x\to a} f(x)\) using algebraic manipulation?
# 2. **Derivative Rules** – Power, product, quotient, chain. Can you apply them without looking?
# 3. **Interpretation** – For any derivative you compute, can you state *what* it represents (speed, growth rate, etc.)?
# 4. **Antiderivative** – Can you find a function \(F\) such that \(F' = f\)?
# 5. **Definite Integral** – Can you translate \(\int_{a}^{b} f(x)\,dx\) into \(F(b)-F(a)\) correctly?
#
# If any answer is “no,” **stop** and review that concept before proceeding.
#
# ---
#
# ### 7. Practice Problems (Do Them Now – No Skipping)
#
# | # | Problem | What to Show |
# |---|---------|--------------|
# | 1 | Compute \(\displaystyle\lim_{x\to3}\frac{x^{2}-9}{x-3}\). | Use factoring, not L’Hôpital (yet). |
# | 2 | Find the derivative of \(g(x)=5x^{3}-4x+7\). | Apply the power rule. |
# | 3 | Differentiate \(h(x)=\sin(x^{2})\). | Use the chain rule correctly. |
# | 4 | Evaluate \(\displaystyle\int_{1}^{4} (2x+1)\,dx\). | Find an antiderivative, then apply FTC. |
# | 5 | Explain in one sentence what the derivative of a position‑time function represents. | Relate to velocity. |
#
# **Do not** look at the answers until you have attempted each problem **on paper**. If you get stuck, go back to the relevant definition and work it out step by step.
#
# ---
#
# ### 8. Final Word from Your Tutor
#
# Calculus is **not** a collection of tricks to memorize; it is a logical extension of algebra and geometry built on the precise notion of limits. Master the foundations, respect the definitions, and you will never be fooled by a “shortcut” that looks neat but is mathematically unsound.
#
# **Your next step:** Complete the practice set, then verify each answer. Only after you can **prove** each result to yourself should you move on to more advanced topics (e.g., multivariable calculus, differential equations).
#
# *No excuses. No shortcuts. No half‑hearted effort.*
